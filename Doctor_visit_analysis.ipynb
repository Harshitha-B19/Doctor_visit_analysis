# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\harsh\appdata\local\programs\python\python311\lib\site-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\harsh\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\harsh\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2022.7.1)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\harsh\appdata\local\programs\python\python311\lib\site-packages (from pandas) (1.24.1)
# Requirement already satisfied: six>=1.5 in c:\users\harsh\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
# !pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.12.2-py3-none-any.whl (293 kB)
#                                               0.0/293.3 kB ? eta -:--:--
#      -                                        10.2/293.3 kB ? eta -:--:--
#      ---                                   30.7/293.3 kB 435.7 kB/s eta 0:00:01
#      -------                               61.4/293.3 kB 409.6 kB/s eta 0:00:01
#      -----------                           92.2/293.3 kB 476.3 kB/s eta 0:00:01
#      -----------------                    143.4/293.3 kB 607.9 kB/s eta 0:00:01
#      -------------------------------------  286.7/293.3 kB 1.0 MB/s eta 0:00:01
#      -------------------------------------- 293.3/293.3 kB 1.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in c:\users\harsh\appdata\local\programs\python\python311\lib\site-packages (from seaborn) (1.24.1)
# Requirement already satisfied: pandas>=0.25 in c:\users\harsh\appdata\local\programs\python\python311\lib\site-packages (from seaborn) (1.5.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in c:\users\harsh\appdata\local\programs\python\python311\lib\site-packages (from seaborn) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\harsh\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\harsh\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\harsh\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.39.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\harsh\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\harsh\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\harsh\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\harsh\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\harsh\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\harsh\appdata\local\programs\python\python311\lib\site-packages (from pandas>=0.25->seaborn) (2022.7.1)
# Requirement already satisfied: six>=1.5 in c:\users\harsh\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.12.2

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv("doctors_visit.csv")

# %%
df.head(50)
# Out:
#     unnamed  visits gender  age  salary  illness  reduced  health private  \
# 0         0       5      F   19      55        1        4       1     yes
# 1         1       6      F   19      45        1        2       1     yes
# 2         2      13      M   19      90        3        0       0      no
# 3         3       2      M   23      15        1        0       0      no
# 4         4       3      M   19      45        2        5       1      no
# 5         5       2      F   19      35        5        1       9      no
# 6         6       5      F   18      55        4        0       2     yes
# 7         7       1      F   19      15        3        0       6     yes
# 8         8       5      F   19      65        2        0       5     yes
# 9         9       1      F   17      15        1        0       0      no
# 10       10       4      M   19      45        1        0       0     yes
# 11       11       2      M   22      25        2        0       2      no
# 12       12       6      M   19      55        3       13       1      no
# 13       13       4      F   21      45        4        7       6      no
# 14       14       3      M   22      25        3        1       0      no
# 15       15       4      F   23      45        5        6       5      no
# 16       16       6      F   22      55        1        4       1     yes
# 17       17       1      F   17      45        1        2       1     yes
# 18       18      15      M   19      90        3        0       0      no
# 19       19       2      M   20      15        1        0       0      no
# 20       20       3      M   22      45        2        5       1      no
# 21       21       3      F   21      35        5        1       9      no
# 22       22       9      F   17      55        4        0       2     yes
# 23       23       4      F   20      15        3        0       6     yes
# 24       24       6      M   20      65        2        0       5     yes
# 25       25       1      M   19      15        2        0       0      no
# 26       26       5      M   22      45        3        0       0     yes
# 27       27       3      M   15      25        1        0       2      no
# 28       28       6      F   23      55        2        0       1      no
# 29       29       6      M   21      65        5        0       6      no
# 30       30       3      M   17      15        4        0       0      no
# 31       31       9      F   17      45        1        0       5      no
# 32       32       2      M   17      25        2        0       2     yes
# 33       33       6      M   18      55        5        0       3     yes
# 34       34       1      F   18      15        4        0       1      no
# 35       35       7      F   19      55        1        0       5      no
# 36       36       5      F   17      15        2        0       6      no
# 37       37       9      F   23      45        5        0       3      no
# 38       38       4      M   22      25        4        4       2     yes
# 39       39      11      F   22      55        3        2       1     yes
# 40       40       2      F   20      15        2        0       7     yes
# 41       41       4      M   20      65        1        0       3      no
# 42       42       3      F   19      15        1        5       4     yes
# 43       43      12      F   19      45        2        1       1      no
# 44       44       4      M   17      25        5        3       1      no
# 45       45       7      M   23      55        4        4       3     yes
# 46       46       4      M   22      85        3        2       0     yes
# 47       47       5      M   22      15        2        1       6     yes
# 48       48       3      M   20      45        1        4       4     yes
# 49       49       5      F   20      75        2        5       3      no
#
#    freepoor freepat nchronic inchronic
# 0        no      no       no        no
# 1        no      no       no        no
# 2        no      no       no        no
# 3       yes      no       no        no
# 4        no      no      yes        no
# 5        no      no      yes        no
# 6        no      no       no        no
# 7        no      no       no        no
# 8        no      no       no        no
# 9        no      no       no        no
# 10       no     yes       no        no
# 11       no      no       no        no
# 12      yes     yes       no        no
# 13       no      no       no        no
# 14      yes      no       no        no
# 15      yes      no       no        no
# 16       no      no       no       yes
# 17       no      no       no       yes
# 18      yes      no       no       yes
# 19       no      no       no       yes
# 20       no      no      yes       yes
# 21       no      no      yes       yes
# 22       no      no       no       yes
# 23       no      no       no       yes
# 24       no      no       no        no
# 25       no      no       no        no
# 26       no     yes       no        no
# 27      yes      no       no       yes
# 28       no     yes       no       yes
# 29      yes      no       no       yes
# 30      yes      no       no       yes
# 31       no      no       no       yes
# 32       no      no       no        no
# 33      yes      no       no        no
# 34       no      no       no        no
# 35       no      no       no       yes
# 36       no      no      yes       yes
# 37       no      no      yes       yes
# 38       no      no       no       yes
# 39       no      no       no       yes
# 40       no      no       no        no
# 41       no      no       no        no
# 42      yes     yes       no        no
# 43       no      no       no        no
# 44      yes     yes       no        no
# 45      yes      no       no        no
# 46      yes      no       no        no
# 47      yes      no       no        no
# 48      yes     yes      yes        no
# 49      yes      no      yes        no

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 13 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   unnamed    51 non-null     int64
#  1   visits     51 non-null     int64
#  2   gender     51 non-null     object
#  3   age        51 non-null     int64
#  4   salary     51 non-null     float64
#  5   illness    51 non-null     int64
#  6   reduced    51 non-null     int64
#  7   health     51 non-null     int64
#  8   private    51 non-null     object
#  9   freepoor   51 non-null     object
#  10  freepat    51 non-null     object
#  11  nchronic   51 non-null     object
#  12  inchronic  51 non-null     object
# dtypes: float64(1), int64(6), object(6)
# memory usage: 5.3+ KB

# %%
df['illness'].value_counts()
# Out:
# 1    14
# 2    13
# 3    10
# 5     7
# 4     7
# Name: illness, dtype: int64

# %%
df['gender'].value_counts()
# Out:
# M    26
# F    25
# Name: gender, dtype: int64

# %% [markdown]
# ### Visualize and analyse maximum, minimum and median salary

# %%
y=list(df.salary)
plt.boxplot(y)
plt.ylabel("Income in thousands")
# Out:
# Text(0, 0.5, 'Income in thousands')

# %% [markdown]
# ### Visualize and analyse reduced activity of male and female separately due to illness

# %%
df.groupby(['gender','reduced']).mean()
# Out:
# C:\Users\harsh\AppData\Local\Temp\ipykernel_11364\1883727358.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['gender','reduced']).mean()
#                   unnamed     visits        age     salary   illness    health
# gender reduced
# F      0        24.307692   6.000000  19.000000  35.769231  2.615385  3.769231
#        1        23.000000  10.000000  19.666667  38.333333  4.000000  6.333333
#        2        19.000000   7.666667  19.333333  48.333333  1.666667  1.000000
#        4         8.000000   5.000000  20.500000  55.000000  1.000000  1.000000
#        5        45.500000   3.000000  19.500000  45.000000  1.500000  3.500000
#        6        15.000000   7.000000  23.000000  45.000000  5.000000  5.000000
#        7        13.000000   2.000000  21.000000  45.000000  4.000000  6.000000
# M      0        22.000000   6.733333  19.400000  43.666667  2.400000  1.533333
#        1        30.500000  10.500000  22.000000  20.000000  2.500000  3.000000
#        2        46.000000   4.000000  22.000000  85.000000  3.000000  0.000000
#        3        44.000000   4.000000  17.000000  25.000000  5.000000  1.000000
#        4        43.666667   4.000000  21.666667  41.666667  3.000000  3.000000
#        5        12.000000   5.000000  20.500000  45.000000  2.000000  1.000000
#        6        50.000000   4.000000  21.000000  67.000000  3.000000  2.000000
#        13       12.000000   6.000000  19.000000  55.000000  3.000000  1.000000

# %% [markdown]
# ### visiualize if any missing values in dataset based on heatmap

# %%
sns.heatmap(df.isnull())
#sns.heatmap(df.isnull(),cbar=False,cmap='cividis')
# Out:
# <Axes: >

# %% [markdown]
# ### findout corelation b/w each of the attribute with other attributes
#
# #illness and health are highly corelated---2.7
# #illness and age are corelated---2.1
# #visits and salary are corelated---0.65

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(),cbar=True,annot=True,cmap='Blues')
# Out:
# C:\Users\harsh\AppData\Local\Temp\ipykernel_11364\183792097.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),cbar=True,annot=True,cmap='Blues')
# <Axes: >

# %% [markdown]
# ### analysing how income of patients effect number of visits

# %%
plt.figure(figsize=(10,10))
plt.scatter(x='salary',y='visits',data=df)
plt.xlabel('salary')
plt.ylabel('visits')
# Out:
# Text(0, 0.5, 'visits')

# %% [markdown]
# ###count of male and female effected by illness

# %%
sns.histplot(df.gender,bins=2)
# Out:
# <Axes: xlabel='gender', ylabel='Count'>

# %% [markdown]
# ###  visulize % od=f people getting govt health insurance due to income and old age and also %of people having private insurance

# %%
label=['yes','no']
Y=df[df['freepoor']=='yes']
N=df[df['freepoor']=='no']

x=[Y.shape[0],N.shape[0]]
plt.figure(figsize=(5,5))
plt.pie(x,labels=label)
plt.title("% getting gvt health insurance")
plt.show()

# %%
#% of ppl having private insurnace
Y=df[df['private']=='yes']
N=df[df['private']=='no']

x=[Y.shape[0],N.shape[0]]
plt.figure(figsize=(5,5))
plt.pie(x,labels=label)
plt.title("% having private insurance")
plt.show()

# %%
#% getting insurance due to old age

Y=df[df['freepat']=='yes']
N=df[df['freepat']=='no']

x=[Y.shape[0],N.shape[0]]
plt.figure(figsize=(5,5))
plt.pie(x,labels=label)
plt.title("% getting insurance due to old age")
plt.show()

# %% [markdown]
# ### horizontal bar chart to analyse reduced days of activity due to illness based on  gender

# %%
db=df.groupby('gender')['reduced'].sum().to_frame().reset_index()
db
# Out:
#   gender  reduced
# 0      F       40
# 1      M       48

# %%
plt.barh(db['gender'],db['reduced'])
plt.title("gender vs reduced acitivity")
plt.ylabel("gender")
plt.xlabel("reduced activity")
plt.show()
